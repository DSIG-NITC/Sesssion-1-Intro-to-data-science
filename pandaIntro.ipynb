# %% [markdown]
# ### This is a short introduction to pandas, geared mainly for new users. You can see more complex recipes in the [Cookbook](https://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Object Creation
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a [DataFrame](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) by passing a numpy array, with a datetime index and labeled columns:

# %%
# generate a list of dates
dates = pd.date_range('2014/11/01', periods=6)
dates
# Out:
# DatetimeIndex(['2014-11-01', '2014-11-02', '2014-11-03', '2014-11-04',
#                '2014-11-05', '2014-11-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
data = np.random.randn(6,4)
data
# Out:
# array([[-0.76602201, -0.31026075,  1.45882835,  0.71352444],
#        [-1.63051985,  0.56236194,  1.68532347, -0.56927092],
#        [-1.56979452, -1.56838081, -0.41097553,  0.36441315],
#        [ 0.22512437,  1.32564327,  0.92009701, -0.54127501],
#        [ 1.47159635,  0.59828774,  0.20404901, -0.33223705],
#        [ 0.60753259,  0.6961236 , -0.16875811,  1.10665864]])

# %%
col_names = ['one','two','three','four']
col_names
# Out:
# ['one', 'two', 'three', 'four']

# %%
df = pd.DataFrame(data)#, index=dates, columns=col_names)
df
# Out:
#           0         1         2         3
# 0 -0.766022 -0.310261  1.458828  0.713524
# 1 -1.630520  0.562362  1.685323 -0.569271
# 2 -1.569795 -1.568381 -0.410976  0.364413
# 3  0.225124  1.325643  0.920097 -0.541275
# 4  1.471596  0.598288  0.204049 -0.332237
# 5  0.607533  0.696124 -0.168758  1.106659

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([1, 2, 3, 4],dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  1   test  foo
# 1  1.0 2013-01-02  1.0  2  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  4  train  foo

# %%
pd.Timestamp('20200123')
# Out:
# Timestamp('2020-01-23 00:00:00')

# %%
pd.Series(1,index=list(range(4)),dtype='float32')
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float32

# %%
np.array([1, 2, 3, 4],dtype='int32')
# Out:
# array([1, 2, 3, 4])

# %%
pd.Categorical(["test","train","test","train"])
# Out:
# [test, train, test, train]
# Categories (2, object): [test, train]

# %% [markdown]
# Having specific [dtypes](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes):

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # Viewing Data
# See the [Basics section](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics)
# See the top & bottom rows of the frame

# %%
df = pd.read_csv('data/fifa18.csv', index_col=0)
df.head()
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B

# %%
df.head()
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B

# %%
df.tail(3)
# Out:
#        Position     Team  Played  Won  Drawn  Lost  Goals for  Goals against  \
# Index
# JPN           2    Japan       3    1      1     1          4              4
# SEN           3  Senegal       3    1      1     1          4              4
# POL           4   Poland       3    1      0     2          2              5
#
#       Goal difference Points Group
# Index
# JPN                 0   4[a]     H
# SEN                 0   4[a]     H
# POL                −3      3     H

# %% [markdown]
# Display the index, columns, and the underlying numpy data

# %%
df.index
# Out:
# Index(['URG', 'RUS', 'KSA', 'EGY', 'ESP', 'POR', 'IRN', 'MOR', 'FRA', 'DEN',
#        'PER', 'AUS', 'CRO', 'ARG', 'NIG', 'ICL', 'BRA', 'SWI', 'SRB', 'COR',
#        'SWE', 'MEX', 'KOR', 'GER', 'BEL', 'ENG', 'TUN', 'PAN', 'COL', 'JPN',
#        'SEN', 'POL'],
#       dtype='object', name='Index')

# %%
df.columns
# Out:
# Index(['Position', 'Team', 'Played', 'Won', 'Drawn', 'Lost', 'Goals for',
#        'Goals against', 'Goal difference', 'Points', 'Group'],
#       dtype='object')

# %%
df.values #inorder to show numpy representation.....
# Out:
# array([[1, 'Uruguay', 3, 3, 0, 0, 5, 0, '5', '9', 'A'],
#        [2, 'Russia(H)', 3, 2, 0, 1, 8, 4, '4', '6', 'A'],
#        [3, 'Saudi Arabia', 3, 1, 0, 2, 2, 7, '−5', '3', 'A'],
#        [4, 'Egypt', 3, 0, 0, 3, 2, 6, '−4', '0', 'A'],
#        [1, 'Spain', 3, 1, 2, 0, 6, 5, '1', '5', 'B'],
#        [2, 'Portugal', 3, 1, 2, 0, 5, 4, '1', '5', 'B'],
#        [3, 'Iran', 3, 1, 1, 1, 2, 2, '0', '4', 'B'],
#        [4, 'Morocco', 3, 0, 1, 2, 2, 4, '−2', '1', 'B'],
#        [1, 'France', 3, 2, 1, 0, 3, 1, '2', '7', 'C'],
#        [2, 'Denmark', 3, 1, 2, 0, 2, 1, '1', '5', 'C'],
#        [3, 'Peru', 3, 1, 0, 2, 2, 2, '0', '3', 'C'],
#        [4, 'Australia', 3, 0, 1, 2, 2, 5, '−3', '1', 'C'],
#        [1, 'Croatia', 3, 3, 0, 0, 7, 1, '6', '9', 'D'],
#        [2, 'Argentina', 3, 1, 1, 1, 3, 5, '−2', '4', 'D'],
#        [3, 'Nigeria', 3, 1, 0, 2, 3, 4, '−1', '3', 'D'],
#        [4, 'Iceland', 3, 0, 1, 2, 2, 5, '−3', '1', 'D'],
#        [1, 'Brazil', 3, 2, 1, 0, 5, 1, '4', '7', 'E'],
#        [2, 'Switzerland', 3, 1, 2, 0, 5, 4, '1', '5', 'E'],
#        [3, 'Serbia', 3, 1, 0, 2, 2, 4, '−2', '3', 'E'],
#        [4, 'Costa Rica', 3, 0, 1, 2, 2, 5, '−3', '1', 'E'],
#        [1, 'Sweden', 3, 2, 0, 1, 5, 2, '3', '6', 'F'],
#        [2, 'Mexico', 3, 2, 0, 1, 3, 4, '−1', '6', 'F'],
#        [3, 'South Korea', 3, 1, 0, 2, 3, 3, '0', '3', 'F'],
#        [4, 'Germany', 3, 1, 0, 2, 2, 4, '−2', '3', 'F'],
#        [1, 'Belgium', 3, 3, 0, 0, 9, 2, '7', '9', 'G'],
#        [2, 'England', 3, 2, 0, 1, 8, 3, '5', '6', 'G'],
#        [3, 'Tunisia', 3, 1, 0, 2, 5, 8, '−3', '3', 'G'],
#        [4, 'Panama', 3, 0, 0, 3, 2, 11, '−9', '0', 'G'],
#        [1, 'Colombia', 3, 2, 0, 1, 5, 2, '3', '6', 'H'],
#        [2, 'Japan', 3, 1, 1, 1, 4, 4, '0', '4[a]', 'H'],
#        [3, 'Senegal', 3, 1, 1, 1, 4, 4, '0', '4[a]', 'H'],
#        [4, 'Poland', 3, 1, 0, 2, 2, 5, '−3', '3', 'H']], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, URG to POL
# Data columns (total 11 columns):
# Position           32 non-null int64
# Team               32 non-null object
# Played             32 non-null int64
# Won                32 non-null int64
# Drawn              32 non-null int64
# Lost               32 non-null int64
# Goals for          32 non-null int64
# Goals against      32 non-null int64
# Goal difference    32 non-null object
# Points             32 non-null object
# Group              32 non-null object
# dtypes: int64(7), object(4)
# memory usage: 4.2+ KB

# %%
df_new = df.copy()

df_new['Position'] = pd.Categorical(df.Won)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, URG to POL
# Data columns (total 11 columns):
# Position           32 non-null category
# Team               32 non-null object
# Played             32 non-null int64
# Won                32 non-null int64
# Drawn              32 non-null int64
# Lost               32 non-null int64
# Goals for          32 non-null int64
# Goals against      32 non-null int64
# Goal difference    32 non-null object
# Points             32 non-null object
# Group              32 non-null object
# dtypes: category(1), int64(6), object(4)
# memory usage: 3.0+ KB

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
df.describe() #25,50,75 denotes quartile ranges
# Out:
#         Position  Played       Won      Drawn       Lost  Goals for  \
# count  32.000000    32.0  32.00000  32.000000  32.000000  32.000000
# mean    2.500000     3.0   1.21875   0.562500   1.218750   3.812500
# std     1.135924     0.0   0.87009   0.715609   0.941323   2.070336
# min     1.000000     3.0   0.00000   0.000000   0.000000   2.000000
# 25%     1.750000     3.0   1.00000   0.000000   0.000000   2.000000
# 50%     2.500000     3.0   1.00000   0.000000   1.000000   3.000000
# 75%     3.250000     3.0   2.00000   1.000000   2.000000   5.000000
# max     4.000000     3.0   3.00000   2.000000   3.000000   9.000000
#
#        Goals against
# count      32.000000
# mean        3.812500
# std         2.249552
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max        11.000000

# %% [markdown]
# Transposing your data

# %%
df.T
# Out:
# Index                URG        RUS           KSA    EGY    ESP       POR  \
# Position               1          2             3      4      1         2
# Team             Uruguay  Russia(H)  Saudi Arabia  Egypt  Spain  Portugal
# Played                 3          3             3      3      3         3
# Won                    3          2             1      0      1         1
# Drawn                  0          0             0      0      2         2
# Lost                   0          1             2      3      0         0
# Goals for              5          8             2      2      6         5
# Goals against          0          4             7      6      5         4
# Goal difference        5          4            −5     −4      1         1
# Points                 9          6             3      0      5         5
# Group                  A          A             A      A      B         B
#
# Index             IRN      MOR     FRA      DEN  ...          KOR      GER  \
# Position            3        4       1        2  ...            3        4
# Team             Iran  Morocco  France  Denmark  ...  South Korea  Germany
# Played              3        3       3        3  ...            3        3
# Won                 1        0       2        1  ...            1        1
# Drawn               1        1       1        2  ...            0        0
# Lost                1        2       0        0  ...            2        2
# Goals for           2        2       3        2  ...            3        2
# Goals against       2        4       1        1  ...            3        4
# Goal difference     0       −2       2        1  ...            0       −2
# Points              4        1       7        5  ...            3        3
# Group               B        B       C        C  ...            F        F
#
# Index                BEL      ENG      TUN     PAN       COL    JPN      SEN  \
# Position               1        2        3       4         1      2        3
# Team             Belgium  England  Tunisia  Panama  Colombia  Japan  Senegal
# Played                 3        3        3       3         3      3        3
# Won                    3        2        1       0         2      1        1
# Drawn                  0        0        0       0         0      1        1
# Lost                   0        1        2       3         1      1        1
# Goals for              9        8        5       2         5      4        4
# Goals against          2        3        8      11         2      4        4
# Goal difference        7        5       −3      −9         3      0        0
# Points                 9        6        3       0         6   4[a]     4[a]
# Group                  G        G        G       G         H      H        H
#
# Index               POL
# Position              4
# Team             Poland
# Played                3
# Won                   1
# Drawn                 0
# Lost                  2
# Goals for             2
# Goals against         5
# Goal difference      −3
# Points                3
# Group                 H
#
# [11 rows x 32 columns]

# %%
df.head()
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B

# %% [markdown]
# Sorting by an axis (In this case, sorting the columns in reverse alphabetical order):

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#        Won          Team  Position Points  Played  Lost Group  Goals for  \
# Index
# URG      3       Uruguay         1      9       3     0     A          5
# RUS      2     Russia(H)         2      6       3     1     A          8
# KSA      1  Saudi Arabia         3      3       3     2     A          2
# EGY      0         Egypt         4      0       3     3     A          2
# ESP      1         Spain         1      5       3     0     B          6
# POR      1      Portugal         2      5       3     0     B          5
# IRN      1          Iran         3      4       3     1     B          2
# MOR      0       Morocco         4      1       3     2     B          2
# FRA      2        France         1      7       3     0     C          3
# DEN      1       Denmark         2      5       3     0     C          2
# PER      1          Peru         3      3       3     2     C          2
# AUS      0     Australia         4      1       3     2     C          2
# CRO      3       Croatia         1      9       3     0     D          7
# ARG      1     Argentina         2      4       3     1     D          3
# NIG      1       Nigeria         3      3       3     2     D          3
# ICL      0       Iceland         4      1       3     2     D          2
# BRA      2        Brazil         1      7       3     0     E          5
# SWI      1   Switzerland         2      5       3     0     E          5
# SRB      1        Serbia         3      3       3     2     E          2
# COR      0    Costa Rica         4      1       3     2     E          2
# SWE      2        Sweden         1      6       3     1     F          5
# MEX      2        Mexico         2      6       3     1     F          3
# KOR      1   South Korea         3      3       3     2     F          3
# GER      1       Germany         4      3       3     2     F          2
# BEL      3       Belgium         1      9       3     0     G          9
# ENG      2       England         2      6       3     1     G          8
# TUN      1       Tunisia         3      3       3     2     G          5
# PAN      0        Panama         4      0       3     3     G          2
# COL      2      Colombia         1      6       3     1     H          5
# JPN      1         Japan         2   4[a]       3     1     H          4
# SEN      1       Senegal         3   4[a]       3     1     H          4
# POL      1        Poland         4      3       3     2     H          2
#
#        Goals against Goal difference  Drawn
# Index
# URG                0               5      0
# RUS                4               4      0
# KSA                7              −5      0
# EGY                6              −4      0
# ESP                5               1      2
# POR                4               1      2
# IRN                2               0      1
# MOR                4              −2      1
# FRA                1               2      1
# DEN                1               1      2
# PER                2               0      0
# AUS                5              −3      1
# CRO                1               6      0
# ARG                5              −2      1
# NIG                4              −1      0
# ICL                5              −3      1
# BRA                1               4      1
# SWI                4               1      2
# SRB                4              −2      0
# COR                5              −3      1
# SWE                2               3      0
# MEX                4              −1      0
# KOR                3               0      0
# GER                4              −2      0
# BEL                2               7      0
# ENG                3               5      0
# TUN                8              −3      0
# PAN               11              −9      0
# COL                2               3      0
# JPN                4               0      1
# SEN                4               0      1
# POL                5              −3      0

# %% [markdown]
# Sorting by values

# %%
df.sort_values(by='Position')
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# SWE           1        Sweden       3    2      0     1          5
# BRA           1        Brazil       3    2      1     0          5
# FRA           1        France       3    2      1     0          3
# COL           1      Colombia       3    2      0     1          5
# CRO           1       Croatia       3    3      0     0          7
# BEL           1       Belgium       3    3      0     0          9
# ESP           1         Spain       3    1      2     0          6
# JPN           2         Japan       3    1      1     1          4
# DEN           2       Denmark       3    1      2     0          2
# MEX           2        Mexico       3    2      0     1          3
# ENG           2       England       3    2      0     1          8
# ARG           2     Argentina       3    1      1     1          3
# RUS           2     Russia(H)       3    2      0     1          8
# POR           2      Portugal       3    1      2     0          5
# SWI           2   Switzerland       3    1      2     0          5
# KOR           3   South Korea       3    1      0     2          3
# TUN           3       Tunisia       3    1      0     2          5
# IRN           3          Iran       3    1      1     1          2
# KSA           3  Saudi Arabia       3    1      0     2          2
# NIG           3       Nigeria       3    1      0     2          3
# PER           3          Peru       3    1      0     2          2
# SRB           3        Serbia       3    1      0     2          2
# SEN           3       Senegal       3    1      1     1          4
# PAN           4        Panama       3    0      0     3          2
# ICL           4       Iceland       3    0      1     2          2
# COR           4    Costa Rica       3    0      1     2          2
# AUS           4     Australia       3    0      1     2          2
# MOR           4       Morocco       3    0      1     2          2
# EGY           4         Egypt       3    0      0     3          2
# GER           4       Germany       3    1      0     2          2
# POL           4        Poland       3    1      0     2          2
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# SWE                2               3      6     F
# BRA                1               4      7     E
# FRA                1               2      7     C
# COL                2               3      6     H
# CRO                1               6      9     D
# BEL                2               7      9     G
# ESP                5               1      5     B
# JPN                4               0   4[a]     H
# DEN                1               1      5     C
# MEX                4              −1      6     F
# ENG                3               5      6     G
# ARG                5              −2      4     D
# RUS                4               4      6     A
# POR                4               1      5     B
# SWI                4               1      5     E
# KOR                3               0      3     F
# TUN                8              −3      3     G
# IRN                2               0      4     B
# KSA                7              −5      3     A
# NIG                4              −1      3     D
# PER                2               0      3     C
# SRB                4              −2      3     E
# SEN                4               0   4[a]     H
# PAN               11              −9      0     G
# ICL                5              −3      1     D
# COR                5              −3      1     E
# AUS                5              −3      1     C
# MOR                4              −2      1     B
# EGY                6              −4      0     A
# GER                4              −2      3     F
# POL                5              −3      3     H

# %% [markdown]
# # Selection

# %% [markdown]
# Note While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.
# See the indexing documentation [Indexing and Selecting Data](https://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing) and [MultiIndex / Advanced Indexing](https://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced)

# %% [markdown]
# ## Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.one

# %%
df['Team']
# Out:
# Index
# URG         Uruguay
# RUS       Russia(H)
# KSA    Saudi Arabia
# EGY           Egypt
# ESP           Spain
# POR        Portugal
# IRN            Iran
# MOR         Morocco
# FRA          France
# DEN         Denmark
# PER            Peru
# AUS       Australia
# CRO         Croatia
# ARG       Argentina
# NIG         Nigeria
# ICL         Iceland
# BRA          Brazil
# SWI     Switzerland
# SRB          Serbia
# COR      Costa Rica
# SWE          Sweden
# MEX          Mexico
# KOR     South Korea
# GER         Germany
# BEL         Belgium
# ENG         England
# TUN         Tunisia
# PAN          Panama
# COL        Colombia
# JPN           Japan
# SEN         Senegal
# POL          Poland
# Name: Team, dtype: object

# %%
df.Team
# Out:
# Index
# URG         Uruguay
# RUS       Russia(H)
# KSA    Saudi Arabia
# EGY           Egypt
# ESP           Spain
# POR        Portugal
# IRN            Iran
# MOR         Morocco
# FRA          France
# DEN         Denmark
# PER            Peru
# AUS       Australia
# CRO         Croatia
# ARG       Argentina
# NIG         Nigeria
# ICL         Iceland
# BRA          Brazil
# SWI     Switzerland
# SRB          Serbia
# COR      Costa Rica
# SWE          Sweden
# MEX          Mexico
# KOR     South Korea
# GER         Germany
# BEL         Belgium
# ENG         England
# TUN         Tunisia
# PAN          Panama
# COL        Colombia
# JPN           Japan
# SEN         Senegal
# POL          Poland
# Name: Team, dtype: object

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:5]
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B

# %%
df['URG':'EGY']
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A

# %% [markdown]
# ## Selecting by Label

# %% [markdown]
# See more in[ Selection by Label](https://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-label)
#
# For getting a cross section using a label

# %%
df.head()
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B

# %%
df.loc['ENG']
# Out:
# Position                 2
# Team               England
# Played                   3
# Won                      2
# Drawn                    0
# Lost                     1
# Goals for                8
# Goals against            3
# Goal difference          5
# Points                   6
# Group                    G
# Name: ENG, dtype: object

# %% [markdown]
# Selecting on a multi-axis by label

# %%
df.loc[:,['Team','Won']]
# Out:
#                Team  Won
# Index
# URG         Uruguay    3
# RUS       Russia(H)    2
# KSA    Saudi Arabia    1
# EGY           Egypt    0
# ESP           Spain    1
# POR        Portugal    1
# IRN            Iran    1
# MOR         Morocco    0
# FRA          France    2
# DEN         Denmark    1
# PER            Peru    1
# AUS       Australia    0
# CRO         Croatia    3
# ARG       Argentina    1
# NIG         Nigeria    1
# ICL         Iceland    0
# BRA          Brazil    2
# SWI     Switzerland    1
# SRB          Serbia    1
# COR      Costa Rica    0
# SWE          Sweden    2
# MEX          Mexico    2
# KOR     South Korea    1
# GER         Germany    1
# BEL         Belgium    3
# ENG         England    2
# TUN         Tunisia    1
# PAN          Panama    0
# COL        Colombia    2
# JPN           Japan    1
# SEN         Senegal    1
# POL          Poland    1

# %% [markdown]
# Showing label slicing, both endpoints are included

# %%
df.loc['URG':'EGY',['Team','Won']]
# Out:
#                Team  Won
# Index
# URG         Uruguay    3
# RUS       Russia(H)    2
# KSA    Saudi Arabia    1
# EGY           Egypt    0

# %%
type(df.loc['URG':'EGY',['Team','Won']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['ENG',['Team','Won']]
# Out:
# Team    England
# Won           2
# Name: ENG, dtype: object

# %%
type(df.loc['ENG',['Team','Won']])
# Out:
# pandas.core.series.Series

# %% [markdown]
# For getting a scalar value

# %%
df.loc['ENG','Won']
# Out:
# 2

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.at['ENG','Won']
# Out:
# 2

# %%
# .at vs .loc

df_copy = df.copy()

df_copy.head(3)
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A

# %%
df_copy.Won.dtype
# Out:
# dtype('int64')

# %%
df_copy.at['URG', 'Won'] = 3.5
df_copy.at['URG', 'Won']
# Out:
# 3

# %%
df_copy.Won.dtype
# Out:
# dtype('int64')

# %%
df_copy.loc[0, 'Won'] = 4.5
df_copy.loc[0, 'Won']
# Out:
# 4.5

# %%
df_copy.Won.dtype
# Out:
# dtype('float64')

# %%
df_copy.loc['URG':'EGY', 'Team']
# Out:
# Index
# URG         Uruguay
# RUS       Russia(H)
# KSA    Saudi Arabia
# EGY           Egypt
# Name: Team, dtype: object

# %%
df_copy.at['URG':'EGY', 'Team']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-e771caabbc31> in <module>
# ----> 1 df_copy.at['URG':'EGY', 'Team']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2198
#    2199         key = self._convert_key(key)
# -> 2200         return self.obj._get_value(*key, takeable=self._takeable)
#    2201
#    2202     def __setitem__(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2857         # use positional
#    2858         col = self.columns.get_loc(col)
# -> 2859         index = self.index.get_loc(index)
#    2860         return self._get_value(index, col, takeable=True)
#    2861
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: 'slice('URG', 'EGY', None)' is an invalid key

# %% [markdown]
# df.at() doesn't have to worry about type conversion and hence is faster. Similar to why C++ is faster than Python.

# %% [markdown]
# ## Selection by Position

# %% [markdown]
# See more in [Selection by Position](Selection by Position)
#
# Select via the position of the passed integers

# %%
df.head()
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B

# %%
df.iloc[3]
# Out:
# Position               4
# Team               Egypt
# Played                 3
# Won                    0
# Drawn                  0
# Lost                   3
# Goals for              2
# Goals against          6
# Goal difference       −4
# Points                 0
# Group                  A
# Name: EGY, dtype: object

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[0,2,4],[0,1, 5]]
# Out:
#        Position          Team  Lost
# Index
# URG           1       Uruguay     0
# KSA           3  Saudi Arabia     2
# ESP           1         Spain     0

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
#
#        Goals against Goal difference Points Group
# Index
# RUS                4               4      6     A
# KSA                7              −5      3     A

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                Team  Played
# Index
# URG         Uruguay       3
# RUS       Russia(H)       3
# KSA    Saudi Arabia       3
# EGY           Egypt       3
# ESP           Spain       3
# POR        Portugal       3
# IRN            Iran       3
# MOR         Morocco       3
# FRA          France       3
# DEN         Denmark       3
# PER            Peru       3
# AUS       Australia       3
# CRO         Croatia       3
# ARG       Argentina       3
# NIG         Nigeria       3
# ICL         Iceland       3
# BRA          Brazil       3
# SWI     Switzerland       3
# SRB          Serbia       3
# COR      Costa Rica       3
# SWE          Sweden       3
# MEX          Mexico       3
# KOR     South Korea       3
# GER         Germany       3
# BEL         Belgium       3
# ENG         England       3
# TUN         Tunisia       3
# PAN          Panama       3
# COL        Colombia       3
# JPN           Japan       3
# SEN         Senegal       3
# POL          Poland       3

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# 'Russia(H)'

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[0,0]
# Out:
# 1

# %% [markdown]
# ## Boolean Indexing
# Using a single column’s values to select data.

# %%
df[df.Won >= 2]
# Out:
#        Position       Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1    Uruguay       3    3      0     0          5
# RUS           2  Russia(H)       3    2      0     1          8
# FRA           1     France       3    2      1     0          3
# CRO           1    Croatia       3    3      0     0          7
# BRA           1     Brazil       3    2      1     0          5
# SWE           1     Sweden       3    2      0     1          5
# MEX           2     Mexico       3    2      0     1          3
# BEL           1    Belgium       3    3      0     0          9
# ENG           2    England       3    2      0     1          8
# COL           1   Colombia       3    2      0     1          5
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# FRA                1               2      7     C
# CRO                1               6      9     D
# BRA                1               4      7     E
# SWE                2               3      6     F
# MEX                4              −1      6     F
# BEL                2               7      9     G
# ENG                3               5      6     G
# COL                2               3      6     H

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met.

# %% [markdown]
# Using the isin method for filtering:

# %%
df[df['Team'].isin(['England','Germany'])]
# Out:
#        Position     Team  Played  Won  Drawn  Lost  Goals for  Goals against  \
# Index
# GER           4  Germany       3    1      0     2          2              4
# ENG           2  England       3    2      0     1          8              3
#
#       Goal difference Points Group
# Index
# GER                −2      3     F
# ENG                 5      6     G

# %% [markdown]
# > **Warning**

# %% [markdown]
# # Getting Data In/Out
# ### CSV
# [Writing to a csv file](https://pandas.pydata.org/pandas-docs/stable/io.html#io-store-in-csv).

# %%
df.to_csv('data/fifa.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('data/fifa.csv')

# %%
df.head()
# Out:
#   Index  Position          Team  Played  Won  Drawn  Lost  Goals for  \
# 0   URG         1       Uruguay       3    3      0     0          5
# 1   RUS         2     Russia(H)       3    2      0     1          8
# 2   KSA         3  Saudi Arabia       3    1      0     2          2
# 3   EGY         4         Egypt       3    0      0     3          2
# 4   ESP         1         Spain       3    1      2     0          6
#
#    Goals against Goal difference Points Group
# 0              0               5      9     A
# 1              4               4      6     A
# 2              7              −5      3     A
# 3              6              −4      0     A
# 4              5               1      5     B

# %%
df['Team']
# Out:
# 0          Uruguay
# 1        Russia(H)
# 2     Saudi Arabia
# 3            Egypt
# 4            Spain
# 5         Portugal
# 6             Iran
# 7          Morocco
# 8           France
# 9          Denmark
# 10            Peru
# 11       Australia
# 12         Croatia
# 13       Argentina
# 14         Nigeria
# 15         Iceland
# 16          Brazil
# 17     Switzerland
# 18          Serbia
# 19      Costa Rica
# 20          Sweden
# 21          Mexico
# 22     South Korea
# 23         Germany
# 24         Belgium
# 25         England
# 26         Tunisia
# 27          Panama
# 28        Colombia
# 29           Japan
# 30         Senegal
# 31          Poland
# Name: Team, dtype: object

# %%
pd.read_csv('data/fifa.csv', index_col=0)
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
# POR           2      Portugal       3    1      2     0          5
# IRN           3          Iran       3    1      1     1          2
# MOR           4       Morocco       3    0      1     2          2
# FRA           1        France       3    2      1     0          3
# DEN           2       Denmark       3    1      2     0          2
# PER           3          Peru       3    1      0     2          2
# AUS           4     Australia       3    0      1     2          2
# CRO           1       Croatia       3    3      0     0          7
# ARG           2     Argentina       3    1      1     1          3
# NIG           3       Nigeria       3    1      0     2          3
# ICL           4       Iceland       3    0      1     2          2
# BRA           1        Brazil       3    2      1     0          5
# SWI           2   Switzerland       3    1      2     0          5
# SRB           3        Serbia       3    1      0     2          2
# COR           4    Costa Rica       3    0      1     2          2
# SWE           1        Sweden       3    2      0     1          5
# MEX           2        Mexico       3    2      0     1          3
# KOR           3   South Korea       3    1      0     2          3
# GER           4       Germany       3    1      0     2          2
# BEL           1       Belgium       3    3      0     0          9
# ENG           2       England       3    2      0     1          8
# TUN           3       Tunisia       3    1      0     2          5
# PAN           4        Panama       3    0      0     3          2
# COL           1      Colombia       3    2      0     1          5
# JPN           2         Japan       3    1      1     1          4
# SEN           3       Senegal       3    1      1     1          4
# POL           4        Poland       3    1      0     2          2
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B
# POR                4               1      5     B
# IRN                2               0      4     B
# MOR                4              −2      1     B
# FRA                1               2      7     C
# DEN                1               1      5     C
# PER                2               0      3     C
# AUS                5              −3      1     C
# CRO                1               6      9     D
# ARG                5              −2      4     D
# NIG                4              −1      3     D
# ICL                5              −3      1     D
# BRA                1               4      7     E
# SWI                4               1      5     E
# SRB                4              −2      3     E
# COR                5              −3      1     E
# SWE                2               3      6     F
# MEX                4              −1      6     F
# KOR                3               0      3     F
# GER                4              −2      3     F
# BEL                2               7      9     G
# ENG                3               5      6     G
# TUN                8              −3      3     G
# PAN               11              −9      0     G
# COL                2               3      6     H
# JPN                4               0   4[a]     H
# SEN                4               0   4[a]     H
# POL                5              −3      3     H

# %% [markdown]
# Using other df.read_csv() arguments

# %% [markdown]
# ### HDF5
# Reading and writing to [HDFStores](https://pandas.pydata.org/pandas-docs/stable/io.html#io-hdf5).
#
# Writing to a HDF5 Store:

# %%
# !conda install -c conda-forge pytables

# %%
df.to_hdf('data/fifa.h5','df')

# %% [markdown]
# Reading from a HDF5 Store:

# %%
pd.read_hdf('data/fifa.h5','df')
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
# POR           2      Portugal       3    1      2     0          5
# IRN           3          Iran       3    1      1     1          2
# MOR           4       Morocco       3    0      1     2          2
# FRA           1        France       3    2      1     0          3
# DEN           2       Denmark       3    1      2     0          2
# PER           3          Peru       3    1      0     2          2
# AUS           4     Australia       3    0      1     2          2
# CRO           1       Croatia       3    3      0     0          7
# ARG           2     Argentina       3    1      1     1          3
# NIG           3       Nigeria       3    1      0     2          3
# ICL           4       Iceland       3    0      1     2          2
# BRA           1        Brazil       3    2      1     0          5
# SWI           2   Switzerland       3    1      2     0          5
# SRB           3        Serbia       3    1      0     2          2
# COR           4    Costa Rica       3    0      1     2          2
# SWE           1        Sweden       3    2      0     1          5
# MEX           2        Mexico       3    2      0     1          3
# KOR           3   South Korea       3    1      0     2          3
# GER           4       Germany       3    1      0     2          2
# BEL           1       Belgium       3    3      0     0          9
# ENG           2       England       3    2      0     1          8
# TUN           3       Tunisia       3    1      0     2          5
# PAN           4        Panama       3    0      0     3          2
# COL           1      Colombia       3    2      0     1          5
# JPN           2         Japan       3    1      1     1          4
# SEN           3       Senegal       3    1      1     1          4
# POL           4        Poland       3    1      0     2          2
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B
# POR                4               1      5     B
# IRN                2               0      4     B
# MOR                4              −2      1     B
# FRA                1               2      7     C
# DEN                1               1      5     C
# PER                2               0      3     C
# AUS                5              −3      1     C
# CRO                1               6      9     D
# ARG                5              −2      4     D
# NIG                4              −1      3     D
# ICL                5              −3      1     D
# BRA                1               4      7     E
# SWI                4               1      5     E
# SRB                4              −2      3     E
# COR                5              −3      1     E
# SWE                2               3      6     F
# MEX                4              −1      6     F
# KOR                3               0      3     F
# GER                4              −2      3     F
# BEL                2               7      9     G
# ENG                3               5      6     G
# TUN                8              −3      3     G
# PAN               11              −9      0     G
# COL                2               3      6     H
# JPN                4               0   4[a]     H
# SEN                4               0   4[a]     H
# POL                5              −3      3     H

# %% [markdown]
# ### Excel
# Reading and writing to [MS Excel](https://pandas.pydata.org/pandas-docs/stable/io.html#io-excel).
#
# Writing to an excel file:

# %%
df.to_excel('data/fifa.xlsx', sheet_name='Group Stage')

# %% [markdown]
# Reading from an excel file:

# %%
# !conda install xlrd

# %%
pd.read_excel('data/fifa.xlsx', 'Group Stage', index_col=0, na_values=['NA'])
# Out:
#        Position          Team  Played  Won  Drawn  Lost  Goals for  \
# Index
# URG           1       Uruguay       3    3      0     0          5
# RUS           2     Russia(H)       3    2      0     1          8
# KSA           3  Saudi Arabia       3    1      0     2          2
# EGY           4         Egypt       3    0      0     3          2
# ESP           1         Spain       3    1      2     0          6
# POR           2      Portugal       3    1      2     0          5
# IRN           3          Iran       3    1      1     1          2
# MOR           4       Morocco       3    0      1     2          2
# FRA           1        France       3    2      1     0          3
# DEN           2       Denmark       3    1      2     0          2
# PER           3          Peru       3    1      0     2          2
# AUS           4     Australia       3    0      1     2          2
# CRO           1       Croatia       3    3      0     0          7
# ARG           2     Argentina       3    1      1     1          3
# NIG           3       Nigeria       3    1      0     2          3
# ICL           4       Iceland       3    0      1     2          2
# BRA           1        Brazil       3    2      1     0          5
# SWI           2   Switzerland       3    1      2     0          5
# SRB           3        Serbia       3    1      0     2          2
# COR           4    Costa Rica       3    0      1     2          2
# SWE           1        Sweden       3    2      0     1          5
# MEX           2        Mexico       3    2      0     1          3
# KOR           3   South Korea       3    1      0     2          3
# GER           4       Germany       3    1      0     2          2
# BEL           1       Belgium       3    3      0     0          9
# ENG           2       England       3    2      0     1          8
# TUN           3       Tunisia       3    1      0     2          5
# PAN           4        Panama       3    0      0     3          2
# COL           1      Colombia       3    2      0     1          5
# JPN           2         Japan       3    1      1     1          4
# SEN           3       Senegal       3    1      1     1          4
# POL           4        Poland       3    1      0     2          2
#
#        Goals against Goal difference Points Group
# Index
# URG                0               5      9     A
# RUS                4               4      6     A
# KSA                7              −5      3     A
# EGY                6              −4      0     A
# ESP                5               1      5     B
# POR                4               1      5     B
# IRN                2               0      4     B
# MOR                4              −2      1     B
# FRA                1               2      7     C
# DEN                1               1      5     C
# PER                2               0      3     C
# AUS                5              −3      1     C
# CRO                1               6      9     D
# ARG                5              −2      4     D
# NIG                4              −1      3     D
# ICL                5              −3      1     D
# BRA                1               4      7     E
# SWI                4               1      5     E
# SRB                4              −2      3     E
# COR                5              −3      1     E
# SWE                2               3      6     F
# MEX                4              −1      6     F
# KOR                3               0      3     F
# GER                4              −2      3     F
# BEL                2               7      9     G
# ENG                3               5      6     G
# TUN                8              −3      3     G
# PAN               11              −9      0     G
# COL                2               3      6     H
# JPN                4               0   4[a]     H
# SEN                4               0   4[a]     H
# POL                5              −3      3     H
